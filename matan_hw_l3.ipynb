# %% [markdown]
# # Домашняя работа
# Математическая логика. Последовательность.

# %% [markdown]
# ## Проверить любым способ, является ли данная логическая формула тавтологией:

# %% [raw]
# (A∨B)→(B∨¬A)
# используя таблицу истинности:
# И∨И=И→И∨Л=И =И
# И∨Л=И→Л∨Л=Л =Л
# Л∨И=И→И∨И=И =И
# Л∨Л=Л→Л∨И=И =И
# это выражение не является тавтологией (при значениях А(И) и В(Л) импликация ЛОЖЬ)

# %% [raw]
# А→(А∨(¬В∧А))
# используя таблицу истинности:
# И→(И∨(¬И∧И)) И→(И∨(Л∧И)) И→(И∨(Л)) И→(И) = И
# И→(И∨(¬Л∧И)) И→(И∨(И∧И)) И→(И∨(И)) И→(И) = И
# Л→(Л∨(¬Л∧Л)) Л→(Л∨(И∧Л)) Л→(Л∨(Л)) Л→(Л) = И
# Л→(Л∨(¬И∧Л)) Л→(Л∨(Л∧Л)) Л→(Л∨(И)) Л→(И) = И
# это выражение является тавтологией (при любых значениях А и В импликация ИСТИНА)

# %% [markdown]
# Сформулируйте словесно высказывания:
# А: сегодня светит солнце; В: сегодня сыро; С: я поеду на дачу.

# %% [raw]
# (¬А∨В)→¬С
# дизьюкция ложного А и В влечет к ложному С
# если не будет солнца или будет сыро я не поеду на дачу
#
# С→(А∨¬В)
# С влечет к дизьюкции А и ложному В
# я поеду на дачу если будет солнце или не будет сыро

# %% [markdown]
# # Математическая логика

# %% [markdown]
# ## 5. На любом курсе каждого факультета есть студенты, сдающие все экзамены на «отлично».

# %% [raw]
# НА ЛЮБОМ курсе КАЖДОГО факультета ЕСТЬ студенты, СДАЮЩИЕ ВСЕ экзамены на отлично.
# ∀ курсе ∀ факультета ∃ студент, СДАЮЩИЙ ∀ экзамены на отлично.
#
# противоположное высказывание:
# ЕСТЬ курсы на НЕКОТОРЫХ факультетах где ВСЕ студенты, НЕ СДАЮТ (лишь) НЕКОТОРЫЕ экзамены на отлично.
# ∃ курсы на ∃ факультетах где ∀ студенты, НЕ СДАЮТ ∃ экзамены на отлично.

# %% [markdown]
# ## 6. Каждый студент философского факультета имеет друга, который умеет решать все логические задачи.

# %% [raw]
# КАЖДЫЙ студент фф ИМЕЕТ друга, который УМЕЕТ решать ВСЕ лог задачи.
# ∀ студент фф ИМЕЕТ друга, который УМЕЕТ решать ∀ лог задачи
#
# противоположное высказывание:
# ЕСТЬ такие студенты фф, которые НЕ ИММЕЮТ друзей, НЕ УМЕЮЩИХ решать лишь НЕКОТОРЫЕ лог задачи.
# ∃ студенты фф, у которых НЕТ друзей, НЕ УМЕЮЩИХ решать НЕ ВСЕ лог задачи  (тавтология?)

# %% [markdown]
# ## 7. В любом самолете на рейсе Вашингтон-Москва присутствует хотя бы один сотрудник силовых органов, в каждой пуговице одежды которого вмонтирован микрофон.

# %% [raw]
# ∀ самолет на рейсе В-М ИМЕЕТ ∃ сотрудника силовых органов, в ∀ пуговица которого ИМЕЕТ микрофорн.
#
# противоположное высказывание:
# ∃ самолеты на рейсе В-М, на борту которых НЕТ такого, что бы ∀ был сотрудником силовых органов, в ∃ пуговицах которого  НЕ БЫЛ бы микрофон.
# Существуют самолеты на рейсе В-М, на борту которого нет совсем сотрудников силовых органов, в некоторых пуговицах которого не было бы микрофона.

# %% [markdown]
# # Множества. Предел последовательности

# %% [markdown]
# ## 8.Представьте в виде несократимой рациональной дроби:
#  0. (216)

# %% [raw]
# а = 0.(216)
# 1000а = 216.(216)
# 1000а = 216+0.(216)
# 999а = 216
# а=216/999
# a=72/333

# %%
print(72/333)
# Out:
# 0.21621621621621623

# %% [markdown]
# ## 9.Представьте в виде несократимой рациональной дроби:
# 1.0(01)

# %% [raw]
# а = 1.0(01)
# 1000а = 1001.(01)
# 1000а = 991+10.(01)
# 990а = 991
# а=991/990

# %%
print(991/990)
# Out:
# 1.001010101010101

# %% [markdown]
# ## 10. Представьте 1 в виде суммы трех рациональных дробей с разными знаменателями и числителем равным 1.

# %% [markdown]
# 1/2+1/3+1/6
# (1*3+1*2+1)/6 = 6/6 =1
# я нашел это подбором
# (зная что 0.(9) равно 1 я постарался прикинуть как получить 0.(9) имея 0.5 (как самую большую дробь) и 0.33 - оказалось что 1/6 = 0.1(6)
# но потом при проверке стало очевидным что при приведении к общему знаменателю 6, числитель тоже стал равен 6)
#
# как лучше было бы решить такую задачу (что есть тру математическим подходом?)

# %%
print(1/2+1/3+1/6)
# Out:
# 0.9999999999999999

# %% [markdown]
# ## 11*. Тоже задание, только в виде суммы шести дробей.

# %% [raw]
# 1/3+1/4+1/5+1/9+1/18+1/20=
# =(6+2+1)/18+(5+4+1)/20=
# =1/2+1/2 =1

# %%
print(1/3+1/4+1/5+1/9+1/18+1/20)
# Out:
# 1.0

# %% [markdown]
# # 12. Найдите значение предела:

# %% [raw]
# lim (1/(1*2)+1/(2*3)+1/(3*4)+...+1/((n-1)*n)  при n→∞
# сумму такого предела можно представить, как:
# (n-1)/n
# (так как например при n=3:
# 1/2 +`1/6 = 4/6=2/3
# при n = 6
# 1/2+1/6+1/12+1/20+1/30=(6+2+1)/12+(3+2)/60=9/12+5/60=(45+5)/60=50/60=5/6)
#
# предел (n-1)/n = 1 , при n→∞

# %% [markdown]
# ## 13. Пользуясь критерием Коши, докажите сходимость последовательности:

# %% [raw]
# аn=sin1/2+sin2/2^2+sin3/2^3+...+sin(n)/2^n
# так как функция sin по модулю меньше или равна 1 и а(n+k) сумма последовательности включает в себя сумму последовательности аn то получаем по формуле Коши выражение:
# 1/n^k < ε , что верно так как возможно при определенных больших значениях к (так как предел такой последовательности при к равной бесконечности стремиться к нулю)

# %% [raw]
# * Какой член последовательности можно взять в качестве предела с точностью 𝜀 = 10−7

# %% [raw]
# N=-log(2)10^-7 = 7/log(10)2 ≈ 23,2
# при n>=24 мы добьемся точности 10^-7

# %% [markdown]
# ## 14*. Пользуясь критерием Коши, докажите расходимость  последовательности:

# %% [raw]
# bn=1/1+1/2+1/3+...+1/n
#
# попытаемся доказать обратное - что последовательность сходиться, те выполняется критерий Коши:
# |bn-bn+k|<𝜀
#
# |(1/1+1/2+1/3+...+1/n)-(1/1+1/2+1/3+...+1/n+k)|<𝜀
# |1/(n+1)+1/(n+2)+...1/(n+k)|<𝜀
#
# 1/(n+k) cамая малая часть в куске ряда разности и таких кусков k и если  k*(1/(n+k)) подставить
#
# |1/(n+1)+1/(n+2)+...1/(n+k)|< k*(1/(n+k)) то не равенство не верно, а следовательно последовательность не сходиться а расходиться
