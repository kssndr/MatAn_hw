# %% [markdown]
# # Тема 7 “Производные функций одного переменного.”

# %% [markdown]
# ## Найти производную функции:

# %% [raw]
# 1)
#
# 𝑦 =1/𝑥 + 2/𝑥^2 − 5/𝑥^3 + 𝑥^1/2 − 𝑥^1/3 + 3/𝑥^1/2
#
# 𝑦' =  -1/𝑥^2 + 4/𝑥^3 − 15/𝑥^4 + 1/𝑥^1/2 - 1/3𝑥^3/2 - 3/2𝑥^3/2

# %% [raw]
# 2)
#
# 𝑦=𝑥(1+𝑥2)^1/2
#
# производное произведения двух функций + производная сложной функции
#
# 𝑦' = 1(1+𝑥2)^1/2 + x 1/(2(1+𝑥2)^1/2)(0+2x)
#
# приведем к общему знаменателю
#
# 𝑦' = ((1+𝑥2)^1/2(1+𝑥2)^1/2 + x^2)/(1+𝑥2)^1/2) = (2x^2 + 1)/(1+𝑥2)^1/2)

# %% [raw]
# 3)
#
# 𝑦= 2𝑥/(1−𝑥^2)
#
# производная деления двух функций
#
# 𝑦' = (2(1−𝑥^2)-2x(0−2𝑥))/(1−𝑥^2)^2 = (2−2𝑥^2+4𝑥^2)/(1−𝑥^2) = (2𝑥^2+2)/(1−𝑥^2)^2

# %% [raw]
# 4)
#
# 𝑦= (𝑥+(𝑥+(𝑥^1/2)))^1/2)^1/2
#
# производная сложной функции
#
# 𝑦' = 1/(2(𝑥+(𝑥+(𝑥^1/2)))^1/2)^1/2) (1 + 1/(2(𝑥+(𝑥^1/2)))^1/2)^1/2)(1+1/(2(𝑥^1/2)))
#
# откроем скобки и приведем к общему знаменателю
#
# 𝑦' = (4(𝑥+(𝑥^1/2))(𝑥^1/2) + 2(𝑥+(𝑥^1/2)) + 2(𝑥^1/2) + 1)/(6(𝑥+(𝑥+(𝑥^1/2)))^1/2)^1/2)(𝑥^1/2))

# %% [markdown]
# ## Найти производную функции с помощью логарифмирования:

# %% [raw]
# 5)
#
# 𝑦 = (𝑥^2+2)^5∙(3𝑥−𝑥^3)^3
#
# 𝑦' = (𝑥^2+2)^5∙(3𝑥−𝑥^3)^3 ∙ (ln((𝑥^2+2)^5∙(3𝑥−𝑥^3)^3))' = (𝑥^2+2)^5∙(3𝑥−𝑥^3)^3 ∙ (ln((𝑥^2+2)^5+ln(3𝑥−𝑥^3)^3))'
#
# вычислим отдельно производную логарифмов:
#
# (ln((𝑥^2+2)^5+ln(3𝑥−𝑥^3)^3))' =  5/(x^2 + 2)(2x) + 3/(3x - x^3)(3 - 3x^2) =
#
# = 10x/x^2+2 + (9-9x^2)/(3 - x^3)
#
# приведем к общему знаменателю и раскроем скобки в числителе
#
# 10x/x^2+2 + (9-9x^2)/(3 - x^3) = (10x(3 - x^3) + (9-9x^2)(x^2+2))/(x^2+2)(3 - x^3) =
# =(30x -10x^4 + 9x^2 + 18 - 9x^4 - 18x^2)/(x^2+2)(3 - x^3) = (30x -19x^4 - 9x^2 + 18)/(x^2+2)(3 - x^3)
#
# вернем в вычисление производной
#
# 𝑦' = (𝑥^2+2)^5∙(3𝑥−𝑥^3)^3 (30x -19x^4 - 9x^2 + 18)/(x^2+2)(3 - x^3)
#
# сократим знаменатель:
#
# 𝑦' = (𝑥^2+2)^4∙(3𝑥−𝑥^3)^3 (30x -19x^4 - 9x^2 + 18)

# %% [raw]
# 6)
#
# 𝑦=(𝑥^1/𝑥)
#
# 𝑦' = (𝑥^1/𝑥) ln((𝑥)^1/𝑥)' = (𝑥^1/𝑥) 1/(𝑥^1/𝑥)((𝑥^1/𝑥))' = ((𝑥^1/𝑥))' = (e^(lnx/x))' = e^(lnx/x)(1/x * lnx)' =
#
# = e^(lnx/x)(-1/x^2 lnx + 1/x 1/x) = e^(lnx/x)(-lnx/x^2 + 1/x^2)= e^(lnx/x)(1-lnx)/x^2

# %% [raw]
# 7)
#
# y = ((2-x^2)^3 (x-1)^2))/(2x^3 - 3x) e^x
#
# y'=((2-x^2)^3 (x-1)^2))/(2x^3 - 3x) e^x (ln(((2-x^2)^3 (x-1)^2))/(2x^3 - 3x) e^x))'
#
# отдельно посчитаем ln'
#
# (ln(((2-x^2)^3 (x-1)^2))/(2x^3 - 3x) e^x)' = 3(ln(2-x^2))' + 2(ln(x-1))' + (ln(1/(2x^3-3x))'+(ln(1/e^x))' =
#
# = -6x/(2-x^2) + 2/(x-1) - (6x^2 - 3)/(2x^3 - 3x) - 1
#
# приведем к общему знаменателю
#
# -6x/(2-x^2) + 2/(x-1) - (6x^2 - 3)/(2x^3 - 3x) - 1 = (2x^6−12x^5−x^4+24x^3+3x^2−12x−6)/(2−x^2)(2x^3−3x)(x−1)
#
# получаем:
#
# y'=((2-x^2)^3 (x-1)^2))/(2x^3 - 3x) e^x (2x^6−12x^5−x^4+24x^3+3x^2−12x−6)/(2−x^2)(2x^3−3x)(x−1) =
#
# = (2-x^2)^2(x-1)(2x^6−12x^5−x^4+24x^3+3x^2−12x−6)/(2−x^2)(2x^3−3x)(x−1) / (2x^3 - 3x)^2 e^x
#
# дальше упрощать проще не становиться

# %% [markdown]
# ## Найти производную функции 𝑦'(𝑥):

# %% [raw]
# 8)*
#
# 𝑥 = (𝑡^2)/(𝑡 − 1)
# 𝑦 = 𝑡/(𝑡^2 − 1)
#
# 𝑦'(𝑥) = 𝑦'(𝑡)/𝑥'(𝑡)
#
# 𝑥'(𝑡) = ((𝑡^2)/(𝑡 − 1))' = (2𝑡(𝑡 − 1) - 𝑡^3)/(𝑡 − 1)^2 = (𝑡^2 − 2𝑡)/(𝑡 − 1)^2
#
# 𝑦'(𝑡) = (𝑡/(𝑡^2 − 1))' = ((𝑡^2 − 1) - 2𝑡^2)/(𝑡^2 − 1)^2 = - ((𝑡^2 + 1)/(𝑡^2 − 1)^2)
#
# 𝑦'(𝑥) = - ((𝑡^2 + 1)/(𝑡^2 − 1)^2)((𝑡 − 1)^2/(𝑡^2 − 2𝑡))
#
# Записываем 1 как 1^2 (в знаменателе)
#
# 𝑦'(𝑥) = - ((𝑡^2 + 1)/(𝑡^2 − 1^2)^2)((𝑡 − 1)^2/(𝑡^2 − 2𝑡))
#
# разность квадратов равна (a+b)(a-b) получаем возможность сократить (𝑡 − 1)^2
#
# 𝑦'(𝑥) = - (𝑡^2 + 1)/(𝑡^2 + 1)^2 (𝑡^2 − 2𝑡)

# %% [raw]
# 9)*
#
# arctg(𝑦/𝑥)=ln(𝑥2+𝑦2)^1/2
#
# (arctg(𝑦/𝑥))' - (ln(𝑥2+𝑦2)^1/2)' = 0
#
# 1/(1+(𝑦/𝑥)^2)(𝑦/𝑥)' - 1/((𝑥2+𝑦2)^1/2)((𝑥2+𝑦2)^1/2)' = 0
#
# 1/(1+(𝑦/𝑥)^2)((𝑦'𝑥-𝑦)/𝑥^2) - 1/((𝑥2+𝑦2)^1/2) 1/2((𝑥2+𝑦2)^1/2)(𝑥2+𝑦2)' = 0
#
# (𝑦'𝑥-𝑦)/(1+(𝑦/𝑥)^2)𝑥^2 - 1/(2(𝑥2+𝑦2))(2𝑥+2𝑦𝑦') = 0
#
# 𝑦'𝑥/(𝑥2+𝑦2) - 𝑦/(𝑥2+𝑦2) - 𝑥/(𝑥2+𝑦2) - 𝑦'𝑦/(𝑥2+𝑦2) = 0
#
# 𝑦'𝑥/(𝑥2+𝑦2) - 𝑦'𝑦/(𝑥2+𝑦2) = 𝑥/(𝑥2+𝑦2) + 𝑦/(𝑥2+𝑦2)
#
# 𝑦'(𝑥-𝑦)/(𝑥2+𝑦2) = (𝑥+𝑦)/(𝑥2+𝑦2)
#
# 𝑦' = (𝑥+𝑦)/(𝑥-𝑦)

# %% [markdown]
# ## Найти производную функции:

# %% [raw]
# 10)
#
# 𝑦 = ln(𝑥 + (𝑥^2 + 1)^1/2)
#
# 𝑦' = 1/(𝑥 + (𝑥^2 + 1)^1/2)(𝑥 + (𝑥^2 + 1)^1/2)'=
#
# = 1/(𝑥 + (𝑥^2 + 1)^1/2)(1 + 2𝑥/2(𝑥^2 + 1)^1/2) =
#
# = 1/(𝑥 + (𝑥^2 + 1)^1/2)(1 + 𝑥/(𝑥^2 + 1)^1/2) =
#
# = (𝑥 + (𝑥^2 + 1)^1/2)/(𝑥 + (𝑥^2 + 1)^1/2)(𝑥^2 + 1)^1/2 =
#
# = 1/(𝑥^2 + 1)^1/2

# %% [raw]
# 11)
#
# 𝑦 = 𝑥∙ln(𝑥 + (𝑥^2 + 1)^1/2) − (𝑥^2 + 1)^1/2
#
# 𝑦' = ln(𝑥 + (𝑥^2 + 1)^1/2) + 𝑥/(𝑥 + (𝑥^2 + 1)^1/2)(𝑥 + (𝑥^2 + 1)^1/2)' − x/(𝑥^2 + 1)^1/2
#
# 𝑦' = ln(𝑥 + (𝑥^2 + 1)^1/2) + 𝑥/(𝑥^2 + 1)^1/2 − 𝑥/(𝑥^2 + 1)^1/2
#
# 𝑦' = ln(𝑥 + (𝑥^2 + 1)^1/2)

# %% [raw]
# 12)
#
# 𝑦 = arcsin sin 𝑥
#
# 𝑦' = 1/(1- sin^2 𝑥)^1/2 (sin 𝑥)' = cos 𝑥 /(1 - sin^2 𝑥)^1/2
#
# дальше упрощать нельзя иначе производная будет не информативна (?)

# %% [markdown]
# ## 13∗. Найти длину 𝑥 и ширину 𝑦 прямоугольника при заданном периметре 𝑃 = 144 см , при которых данный прямоугольник имеет наибольшую площадь 𝑆.

# %% [raw]
# P = 2(a+b)
# S = ab
#
# выразим основную функцию площади через одну переменную
#
# P = 2(a+b) = 144
# a = 72-b
# S = (72-b)b = 72b - b^2
# эта функция описывает зависимость площади от параметра b - другими словами - показывает как площадь меняется с изменением размера b от - бесконечности до + бесконечности. (Однако нас не интересует все что меньше нуля)
# для исследования функции нам потребуется производная функции - а именно нам нужно узнать где производная меняет свой знак - проходит через ноль - вебь именно в этот момент функция имеет макисимальное значение - что и нужно для решения задачи
#
# S' = 72 - 2b
#
# 72 - 2b = 0
# b = 72/2
# b = 36
#
# a = 72 - 36 = 36
#
# Ответ:
# максимальную площадь при заданном периметре будет еметь квадрат со стороной 36 см
