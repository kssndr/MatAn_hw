# %% [markdown]
# # Урок 1. Вебинар “Вводный урок”

# %% [markdown]
# В школе математику не понимал, зубрил, сдавал и тут же забывал.
# Технический вуз закончил с отличием, но и там математику по большей части зубрил, потому что многое было не понятно, интернета не было, спросить тоже не у кого(преподов чаще отвечали - что тут не понятного?- идите думайте/школьная программа).
# В общем не считал себя математиком, хотя инженер по призванию(люблю это дело).
# Сейчас приходиться разбираться с азов поэтому долго - а так все кажется очень простым когда разберешься.
# Математика нравиться все больше и больше - просто отдых для меня. очень нравиться разбираться с задачами.
