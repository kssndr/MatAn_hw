# %% [markdown]
# # Тема “Предел функции”

# %% [markdown]
# ## Найти предел функции:

# %% [raw]
# 1)
#
# lim(x→∞) (23-2x^2)(3x^2+17)^2/(4x6+x-1) = ∞/∞
#
# lim(x→∞) (-2x^2*9x^4)/(4x^6+x-1) = lim(x→∞) (-18x^6)/(4x^6+x-1) =-18/4=-4.5

# %% [markdown]
# 2)
#
# lim(x→∞) (97-2x)^3/2x(3x^2+15)+8x = ∞/∞
#
# lim(x→∞) -8x^3/6x^3 = lim(x→∞) -8/6 = -1 1/3

# %% [raw]
# 3)
#
# lim(x→∞) (2x^3 + 13x(x+18))/((27-x)(2x+19)^2) = ∞/∞
#
# lim(x→∞) 2x^3/-4x^3 = -1/2

# %% [raw]
# 4)
#
# lim(x→6) (x^2-36)/(x^2-x-30) = 0/0
#
# представили числитель как произведение (x-6)(x+5)
#
# lim(x→6) ((x-6)(x+6))/((x-6)(x+5))
#
#   сокращаем (x-6)
#
# lim(x→6) (x+6)/(x+5) = 12/11 = 1 1/11

# %% [raw]
# 5)
#
# lim(x→7) (x^2-49)/(x^2-13x+42) = 0/0
#
# lim(x→7) (x-7)(x+7)/(x-6)(x-7) = lim(x→7) (x+7)/(x-6)=14

# %% [raw]
# 6)
#
# lim(x→7) ((x+2)^1/2 - (x+20)^1/3)/((x+9)^1/4 - 2)=0/0
#
# избавимся от всех корней, сперва от 1/2 (представим числитель как разность квадратов)
#
# lim(x→7) ((x+2)^1/2 - (x+20)^1/3)((x+2)^1/2 + (x+20)^1/3)/((x+9)^1/4 - 2)((x+2)^1/2 + (x+20)^1/3)
#
# lim(x→7) ((x+2 - (x+20)^2/3)/((x+9)^1/4 - 2)((7+2)^1/2 + (7+20)^1/3) = 1/6 lim(x→7) ((x+2 - (x+20)^2/3)/((x+9)^1/4-2)
#
# теперь от 1/3 (представим числитель как разность кубов)
#
# 1/6 lim(x→7) ((x+2)^3 - (x+20)^2)/((x+9)^1/4-2)((x+2)^2 + (x+2)(x+20)^2/3 + (x+20)^4/3) =
#
# = 1/6 lim(x→7) ((x+2)^3 - (x+20)^2)/((7+9)^1/4-2)((7+2)^2 + (7+2)(7+20)^2/3 + (7+20)^4/3) =
# = 1/(6 * 243) lim(x→7) ((x+2)^3 - (x+20)^2)/((x+9)^1/4-2)
#
# теперь от 1/4 (два раза представим как разность квадратов)
#
# 1/(6 * 243) lim(x→7) ((x+2)^3 - (x+20)^2)((x+9)^1/4 + 2)/((x+9)^1/2 - 4) =
# = 1/(6 * 243) lim(x→7) ((x+2)^3 - (x+20)^2)((7+9)^1/4 + 2)/((x+9)^1/2- 4) =
# = 4/(6 * 243) lim(x→7) ((x+2)^3 - (x+20)^2)/((x+9)^1/2 - 4)
#
# второй раз
#
# 1/(6 * 243) lim(x→7) ((x+2)^3 - (x+20)^2)((x+9)^1/2 + 4)/((x+9) - 16) =
# = 1/(6 * 243) lim(x→7) ((x+2)^3 - (x+20)^2)((7+9)^1/2 + 4)/((x+9-16) =
# = (4*8)/(6 * 243) lim(x→7) ((x+2)^3 - (x+20)^2)/(x-7)
#
# теперь перемножим все в числителе:
#
# (4*8)/(6 * 243) lim(x→7) (x^3 +6x^2 + 12x +8 - x^2 - 40x - 400)/(x-7) =
# = (4*8)/(6 * 243) lim(x→7) (x^3 +5x^2 -28x - 392)/(x-7)
#
# теперь выделим из числителя (x-7)
#
# x^3 +5x^2 - 28x - 392 | (x-7) = x^2+12x+56
# x^3 -7x^2
# ----------
#      12x^2 - 28x
#      12x^2 - 84x
#      -----------
#              56x-392
#              56x-392
#
# осталось сократить (x-7) в числителе и знаменателе
#
# (4*8)/(6 * 243) lim(x→7) (x-7)(x^2+12x+56)/(x-7) = (4*8)/(6 * 243) lim(x→7) (x^2+12x+56)
#
# подставим 7
#
# (4*8)/(6 * 243) lim(x→7) (7^2+12*7+56) = 16/3*243 (49+84+56) = 16*189/3*243 = 16 * 63/243 = 16 * 21/81 = 112/27 =
#  = 4 4/27

# %% [raw]
# 7)
#
# lim(x→0) (3x tg4x)/(1-cos4x) = 0/0
#
# lim(x→0) (3x tg4x)/2sin^2 4x/2 = 3x*4x*2/4x^2 = 3x*2/4x = 3/2 = 1.5

# %% [raw]
# 8)
#
# lim(x→0) 2^1/2 x^2 sin4x/(1-cos2x)^3/2 = 0/0
#
# избавимся от квадратного корня в знаменателе (и от косинуса)
#
# lim(x→0) 2^1/2 x^2 sin4x/(2^1/2 sinx)^3
#
# выразим куб через произведение
#
# lim(x→0) 2^1/2 x^2 sin4x/(2^1/2 sinx 2^1/2 sinx 2^1/2 sinx)
#
# сократим корень из 2 и получим 2 в знаменателе
#
# lim(x→0) x^2 sin4x/2(sinx sinx sinx)
#
# получаем
#
# lim(x→0) x^2 sin4x/2(sinx sinx sinx) = 1*4/2=2

# %% [raw]
# 9)
#
# lim(x→∞) (4x/(4x+3))^(5x^2/(7x-1)) = 1^∞
#
# используем второй замечательный предел
# перевернем дробь через минус в степени
#
# lim(x→∞) ((4x+3)/4x)^(-5x^2/(7x-1) = lim(x→∞) ((1+3/4x)^(-5x^2/(7x-1))
#
# приведем ко второму замечательному пределу
#
# lim(x→∞) ((1+3/4x)^(-5x^2/(7x-1) =  lim(x→∞) ((1+3/4x)^((-5x^2/(7x-1))(3/4x)(4x/3) =
#
# = e^lim(x→∞)((-5x^2/(7x-1))(3/4x) = e^lim(x→∞)((-5x/(7x-1))(3/4) =e^lim(x→∞)-15x/4x(7-1/x) =
# = e^lim(x→∞)-15/4(7-1/x) = e^-15/4(7-1/∞) = e^-15/4(7-0) =e^-15/28 = 0.5856692901447937

# %%
import numpy as np

np.exp(-0.535)
# Out:
# 0.5856692901447937

# %% [raw]
# 10)
#
# lim(x→+∞) (ln(x^2-x+1))/(ln(x^10+x+1)) = ∞/∞
#
# lim(x→+∞) (ln(x^2-x+1))/(ln(x^10+x+1)) = lim(x→+∞) (ln(x-1)^2)/(ln(x^10(1+x/x^10+1/x^10)) =
#
# = lim(x→+∞) (ln(x-1)^2)/(ln(x^10(1+x/x^10+1/x^10)) = lim(x→+∞) (ln(∞-1)^2)/(ln(∞^10(1+∞/∞^10+1/∞^10))=
# = lim(x→+∞) (ln(∞-1)^2)/(ln(∞^10(1+0+0)) = lim(x→+∞) (ln(∞-1)^2)/(ln(∞^10) = lim(x→+∞) (2 ln(∞))/10(ln(∞) =
# = 2 ∞/10 ∞ = 2/10 =1/5

# %% [raw]
# 11)
#
# lim(x→0) (5^x - 1)/x = 0/0
#
# мы знаем следствие второго замечательного предела lim(x→0) (e^x - 1)/x = 1 или ln e отсюда
#
# lim(x→0) (5^x - 1)/x = ln5 = 1.6
